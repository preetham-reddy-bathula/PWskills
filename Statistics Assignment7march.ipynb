# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q1. The three measures of central tendency are mean, median, and mode.

# %% [markdown]
# Q2. The mean is the arithmetic average of a dataset, calculated by adding up all the data points and dividing by the number of data points. The median is the middle value in a dataset when the data points are sorted in ascending order. The mode is the value that occurs most frequently in a dataset. All three measures are used to describe the central location of a dataset.

# %% [markdown]
# Q3. Using the given height data:
#
# Mean: (sum of all heights) / 16 = 2830.3 / 16 ≈ 176.89
#
# Sorted data: [172.5, 175, 175, 176, 176.2, 176.5, 177, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180]
#
# Median: (176.5 + 177) / 2 = 353 / 2 ≈ 176.5
#
# Mode: 177, 178 (both occur 3 times)

# %% [markdown]
# Q4. To find the standard deviation for the given data [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5], follow these steps:
#
# Calculate the mean (already done in Q3): 2830.3 / 16 ≈ 176.89
#
# Find the squared differences between each data point and the mean:
#
# [(178 - 176.89)^2, (177 - 176.89)^2, (176 - 176.89)^2, ...]
# ≈ [1.2321, 0.0121, 0.7921, 0.0121, 1.7284, 1.2321, 3.5689, 4.4736, 9.7321, 3.5689, 4.0401, 0.4804, 0.0121, 19.3929, 1.2321, 0.1521]
#
# Calculate the mean of these squared differences (sum all the squared differences and divide by the number of data points):
#
# (1.2321 + 0.0121 + 0.7921 + ... + 0.1521) / 16 ≈ 5.6788
#
# Take the square root of the mean of squared differences to find the standard deviation:
#
# √5.6788 ≈ 2.38
#
# So, the standard deviation for the given dataset is approximately 2.38. The standard deviation is a measure of dispersion that quantifies the average amount by which individual data points differ from the mean. A higher standard deviation indicates a wider spread in the data, while a lower standard deviation indicates a more closely clustered dataset around the mean.

# %% [markdown]
# Q5. Measures of dispersion, such as range, variance, and standard deviation, describe the spread or variability within a dataset. The range is the difference between the maximum and minimum values, variance is the average of squared differences from the mean, and standard deviation is the square root of the variance. These measures help determine how much the data points are spread out from the center.
#
# Example: For a dataset with exam scores of [70, 75, 85, 90, 95], the range is 95 - 70 = 25, the variance is ≈ 87.5, and the standard deviation is ≈ 9.35.

# %% [markdown]
# Q6. A Venn diagram is a visual representation of relationships between sets, using circles or other shapes to depict overlapping areas representing common elements between the sets.

# %% [markdown]
# Q7. For the given sets A = (2, 3, 4, 5, 6, 7) and B = (0, 2, 6, 8, 10):
#
# (i) A ∩ B = (2, 6) (elements common to both sets)
#
# (ii) A ⋃ B = (0, 2, 3, 4, 5, 6, 7, 8, 10) (all unique elements in either set)

# %% [markdown]
# Q8. Skewness is a measure of the asymmetry of the probability distribution of a dataset around its mean. It can be positive (right-skewed) if the tail on the right is longer, or negative (left-skewed) if the tail on the left is longer.

# %% [markdown]
# Q9. If a dataset is right-skewed, the median will be lower than the mean because the longer tail pulls the mean to the right.

# %% [markdown]
# Q10. The difference between covariance and correlation is that covariance measures the direction and strength of the relationship between two variables, while correlation measures only the direction and strength of the relationship.
#
# Covariance measures how much two variables vary together. A positive covariance indicates that both variables tend to increase or decrease together, while a negative covariance indicates that one variable tends to increase when the other decreases. However, the covariance value does not provide any information about the strength of the relationship.
#
# Correlation measures the strength and direction of the linear relationship between two variables. The correlation coefficient ranges from -1 to 1, with -1 indicating a perfect negative linear relationship, 0 indicating no linear relationship, and 1 indicating a perfect positive linear relationship. Correlation is a standardized measure that allows us to compare the strength of relationships between different pairs of variables.
#
# These measures are used in statistical analysis to assess the relationship between two variables. They are useful in identifying patterns in the data and in predicting future outcomes.

# %% [markdown]
# Q11. The formula for calculating the sample mean is:
#
# sample mean = (sum of all values in the dataset) / (number of values in the dataset)
#
# For example, let's say we have the following dataset:
#
# 3, 5, 2, 7, 1
#
# To calculate the sample mean, we add up all the values and divide by the number of values:
#
# sample mean = (3 + 5 + 2 + 7 + 1) / 5
# sample mean = 18 / 5
# sample mean = 3.6
#
# Therefore, the sample mean for this dataset is 3.6.

# %% [markdown]
# Q12. For a normal distribution, the measures of central tendency (mean, median, and mode) are all equal. This is because the normal distribution is symmetric around its mean.

# %% [markdown]
# Q13. Covariance measures the direction and strength of the relationship between two variables, while correlation measures only the direction and strength of the linear relationship between two variables. Covariance can be positive or negative, while correlation is always between -1 and 1. Correlation is a standardized measure that allows us to compare the strength of relationships between different pairs of variables, while covariance is not standardized.

# %% [markdown]
# Q14. Outliers can greatly affect measures of central tendency and dispersion. In measures of central tendency, outliers can pull the mean away from the majority of the data, while the median is less affected. For example, consider the following dataset:
#
# 10, 15, 20, 25, 30, 500
#
# The mean is heavily influenced by the outlier (500), so the mean would be 91.67, while the median would be 22.5, which is a better representation of the center of the dataset.
#
# In measures of dispersion, outliers can greatly affect the range and standard deviation. For example, consider the following dataset:
#
# 10, 15, 20, 25, 30, 500
#
# The range would be 490, which is heavily influenced by the outlier (500). Similarly, the standard deviation would be 182.69, which is also heavily influenced by the outlier.
#
# Therefore, it is important to be aware of outliers when analyzing data, and to consider using alternative measures of central tendency and dispersion, such as the median and interquartile range, which are less affected by outliers.
